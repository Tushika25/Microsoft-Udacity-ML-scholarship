# %%
import pandas as pd
data = pd.read_csv("C:\\Users\\Shri\\Downloads\\cybercleandataset.csv")

# %%
data.shape
# Out:
# (1065, 2)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import numpy as np

# %%
vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(data['text'])

# %%
print(X)
# Out:
#   (0, 3090)	0.2700324419667605
#   (0, 1981)	0.2856442760747583
#   (0, 23)	0.3452633988567975
#   (0, 716)	0.39498835661589743
#   (0, 416)	0.3573728781708789
#   (0, 1290)	0.1990322758307527
#   (0, 3524)	0.3452633988567975
#   (0, 2472)	0.39498835661589743
#   (0, 2291)	0.3573728781708789
#   (1, 2456)	0.45170380040594127
#   (1, 1761)	0.24103839228931875
#   (1, 2755)	0.3207593943007071
#   (1, 2490)	0.45170380040594127
#   (1, 2795)	0.478351353087354
#   (1, 3019)	0.3795019555287707
#   (1, 1290)	0.24103839228931875
#   (2, 3129)	0.3899354896072287
#   (2, 657)	0.36821332569027293
#   (2, 1061)	0.3310790412016499
#   (2, 449)	0.35280120511860563
#   (2, 108)	0.3899354896072287
#   (2, 1505)	0.3899354896072287
#   (2, 1716)	0.36821332569027293
#   (2, 1290)	0.19648616629774834
#   (3, 2828)	0.21427797027997222
#   :	:
#   (1062, 1883)	0.27670337987729354
#   (1062, 1068)	0.396735658214624
#   (1062, 1244)	0.38012969267000135
#   (1062, 2165)	0.3333201048676929
#   (1062, 257)	0.396735658214624
#   (1063, 533)	0.3271718002478505
#   (1063, 734)	0.3271718002478505
#   (1063, 2820)	0.3271718002478505
#   (1063, 2319)	0.3271718002478505
#   (1063, 604)	0.3271718002478505
#   (1063, 2075)	0.3271718002478505
#   (1063, 2534)	0.3089460176160929
#   (1063, 1906)	0.2708597154436976
#   (1063, 3591)	0.24303371062274187
#   (1063, 3427)	0.254827065855789
#   (1063, 1476)	0.254827065855789
#   (1064, 3291)	0.40693093480379067
#   (1064, 3150)	0.40693093480379067
#   (1064, 1263)	0.38426200441842956
#   (1064, 1883)	0.2680036270485245
#   (1064, 2514)	0.3557025297000258
#   (1064, 1906)	0.3368908846138146
#   (1064, 3354)	0.2754691617718184
#   (1064, 1943)	0.2781969447867558
#   (1064, 1814)	0.23671636931518344

# %%
true_k = 2
model = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
model.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=100,
#        n_clusters=2, n_init=1, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()

# %%
terms
# Out:
# ['000',
#  '05',
#  '06',
#  '08',
#  '10',
#  '100',
#  '100000',
#  '100k',
#  '10fold',
#  '11',
#  '12',
#  '120',
#  '122',
#  '14',
#  '15',
#  '160',
#  '175000',
#  '18',
#  '18year',
#  '1944',
#  '1989',
#  '1nomore1',
#  '20',
#  '2018',
#  '21',
#  '25',
#  '28',
#  '285',
#  '2a',
#  '2b',
#  '2nd',
#  '30pm',
#  '32',
#  '3310',
#  '3rd',
#  '3t',
#  '40',
#  '400',
#  '427000',
#  '44',
#  '45',
#  '4billybob2',
#  '50',
#  '500',
#  '56',
#  '5ile',
#  '60',
#  '666',
#  '70',
#  '7086',
#  '745',
#  '78',
#  '80',
#  '8th',
#  '90',
#  '99',
#  '990s',
#  '999',
#  'aa3',
#  'abc',
#  'ability',
#  'able',
#  'abo',
#  'abortion',
#  'abortions',
#  'abos',
#  'abso',
#  'absolute',
#  'absolutely',
#  'absurdly',
#  'abt',
#  'abuse',
#  'accentismproj',
#  'accept',
#  'acceptable',
#  'accepting',
#  'acco',
#  'accompagn',
#  'according',
#  'account',
#  'accounts',
#  'accurate',
#  'accused',
#  'achievements',
#  'acknowledged',
#  'act',
#  'acting',
#  'action',
#  'actively',
#  'actor',
#  'actors',
#  'actual',
#  'actuall',
#  'actually',
#  'adaptation',
#  'add',
#  'address',
#  'administration',
#  'admired',
#  'admiring',
#  'admission',
#  'admit',
#  'admitting',
#  'aesthetically',
#  'af',
#  'affects',
#  'affirmative',
#  'afightforallofus',
#  'afraid',
#  'afro',
#  'aged',
#  'agenda',
#  'ages',
#  'ago',
#  'agree',
#  'agreed',
#  'ah',
#  'ahole',
#  'aight',
#  'aiming',
#  'aimlessly',
#  'ain',
#  'ainge',
#  'aint',
#  'air',
#  'airfare',
#  'aka',
#  'al',
#  'album',
#  'alerted',
#  'ali',
#  'aliens',
#  'alive',
#  'allah',
#  'alleged',
#  'alley',
#  'alliance',
#  'allow',
#  'allowed',
#  'alma',
#  'alpha',
#  'alright',
#  'alt',
#  'alteri',
#  'alternate',
#  'alyssa',
#  'amazes',
#  'amazing',
#  'amazon',
#  'americ',
#  'america',
#  'american',
#  'amit',
#  'amp',
#  'amphibian',
#  'amsterdam',
#  'amy',
#  'analysis',
#  'analyze',
#  'andrewscheer',
#  'andy',
#  'anew',
#  'anfield',
#  'angle',
#  'angry',
#  'ani',
#  'animal',
#  'anime',
#  'animematsuri',
#  'ann',
#  'anna',
#  'annan',
#  'annoying',
#  'anoosh',
#  'anorexic',
#  'ans',
#  'answer',
#  'antagonism',
#  'anthro',
#  'anti',
#  'antisemitism',
#  'antonio',
#  'anybody',
#  'anymore',
#  'anytime',
#  'apart',
#  'app',
#  'appalling',
#  'apparently',
#  'appeals',
#  'appearances',
#  'apple',
#  'applications',
#  'applying',
#  'appreciate',
#  'approval',
#  'approves',
#  'april',
#  'aquarius',
#  'ar',
#  'arab',
#  'arabism',
#  'arabists',
#  'archaeolo',
#  'architect',
#  'arctic',
#  'aren',
#  'arent',
#  'argue',
#  'arguing',
#  'argument',
#  'arguments',
#  'aricle',
#  'arizona',
#  'arm',
#  'armed',
#  'army',
#  'aroace',
#  'arran',
#  'arrested',
#  'arrogant',
#  'arse',
#  'arsenal',
#  'artem',
#  'artemis',
#  'article',
#  'articles',
#  'artist',
#  'artisticfcuk',
#  'artists',
#  'arts',
#  'arual',
#  'asda',
#  'asfuck',
#  'ashamed',
#  'ashley',
#  'asia',
#  'asians',
#  'ask',
#  'asked',
#  'asking',
#  'asks',
#  'ass',
#  'assam',
#  'assassinated',
#  'assault',
#  'asscheek',
#  'assed',
#  'assemble',
#  'assert',
#  'assez',
#  'asshole',
#  'assholes',
#  'assigns',
#  'assume',
#  'assuming',
#  'asswednesday',
#  'ate',
#  'atheism',
#  'atlanta',
#  'atlantic',
#  'atleast',
#  'atonement',
#  'attack',
#  'attacked',
#  'attacking',
#  'attacks',
#  'atte',
#  'attempt',
#  'attend',
#  'attended',
#  'attending',
#  'attension',
#  'attention',
#  'attic',
#  'attitude',
#  'attn',
#  'attorneys',
#  'attract',
#  'attributes',
#  'audience',
#  'august',
#  'auschwitz',
#  'austrian',
#  'authentic',
#  'authoritarian',
#  'autism',
#  'automation',
#  'avail',
#  'avait',
#  'avancer',
#  'average',
#  'avfc',
#  'aw',
#  'awa',
#  'awake',
#  'award',
#  'aware',
#  'awaren',
#  'away',
#  'awe',
#  'awesome',
#  'awkward',
#  'ayo',
#  'babbles',
#  'babies',
#  'baby',
#  'backing',
#  'backpacks',
#  'backward',
#  'bad',
#  'bag',
#  'baiting',
#  'bake',
#  'bakers',
#  'balance',
#  'ball',
#  'ballot',
#  'ban',
#  'banalisation',
#  'banned',
#  'bannon',
#  'baptized',
#  'bar',
#  'barack',
#  'barbar',
#  'barr',
#  'based',
#  'bash',
#  'basically',
#  'basis',
#  'bastard',
#  'bathroom',
#  'battle',
#  'baying',
#  'bbcpointswest',
#  'bc',
#  'beach',
#  'beast',
#  'beat',
#  'beating',
#  'beats',
#  'beautiful',
#  'bebop',
#  'beca',
#  'bed',
#  'bee',
#  'beg',
#  'began',
#  'begging',
#  'beginning',
#  'bei',
#  'beli',
#  'beliefs',
#  'believe',
#  'believing',
#  'bellaluna468',
#  'besoins',
#  'best',
#  'bet',
#  'better',
#  'bettyannroyal1',
#  'betw',
#  'bf',
#  'bgbiskite',
#  'bhi',
#  'bias',
#  'bieber',
#  'big',
#  'bigger',
#  'biggest',
#  'bigly',
#  'bigot',
#  'bigotry',
#  'bigots',
#  'bike',
#  'bikes',
#  'billboard',
#  'billie',
#  'billion',
#  'bills',
#  'bimbo',
#  'bio',
#  'biological',
#  'birds',
#  'bisexual',
#  'bishhh',
#  'bit',
#  'bitch',
#  'bitcheness',
#  'bitches',
#  'bites',
#  'bitter',
#  'blac',
#  'black',
#  'blackface',
#  'blackmail',
#  'blackness',
#  'blackwork',
#  'blaming',
#  'bldg',
#  'bless',
#  'blind',
#  'blindness',
#  'blizzard',
#  'blm',
#  'bloated',
#  'block',
#  'blocked',
#  'blocking',
#  'blogspots',
#  'bloke',
#  'blood',
#  'bloody',
#  'blow',
#  'blown',
#  'blue',
#  'bluelivesmatter',
#  'bluemanc71',
#  'blueplanet',
#  'bmw',
#  'board',
#  'body',
#  'boi',
#  'boiling',
#  'bomb',
#  'bombers',
#  'bombing',
#  'bombs',
#  'bone',
#  'boo',
#  'boob',
#  'boogeyman',
#  'boogy',
#  'book',
#  'books',
#  'boomerang',
#  'boot',
#  'booty',
#  'bop',
#  'border',
#  'borders',
#  'boring',
#  'born',
#  'bossing',
#  'bot',
#  'bots',
#  'bottle',
#  'bottles',
#  'bought',
#  'boujie',
#  'bourgeois',
#  'bout',
#  'box',
#  'boxing',
#  'boy',
#  'boycott',
#  'boyfriends',
#  'bozo',
#  'brag',
#  'brai',
#  'brain',
#  'brake',
#  'brandon',
#  'brazil',
#  'bre',
#  'break',
#  'breather',
#  'breathing',
#  'breeding',
#  'breeds',
#  'bri',
#  'brick',
#  'brigade',
#  'brightond',
#  'bringing',
#  'britain',
#  'british',
#  'brits',
#  'bro',
#  'broad',
#  'brock',
#  'broke',
#  'broken',
#  'bron',
#  'brothers',
#  'brought',
#  'brown',
#  'brrr',
#  'bruuuuhh',
#  'bst',
#  'bts',
#  'btw',
#  'bu',
#  'buddies',
#  'buddy',
#  'buffon',
#  'buffoon',
#  'buggin',
#  'buhari',
#  'build',
#  'building',
#  'built',
#  'bullshit',
#  'bully',
#  'bullying',
#  'bum',
#  'bunch',
#  'burglars',
#  'bus',
#  'bushnell',
#  'bussed',
#  'busts',
#  'butt',
#  'buy',
#  'bwahahaaa',
#  'bye',
#  'ca',
#  'cafe',
#  'cage',
#  'cairns',
#  'cakes',
#  'cal',
#  'called',
#  'calling',
#  'calls',
#  'calm',
#  'came',
#  'cameras',
#  'camilalloyd7',
#  'camille',
#  'campus',
#  'canadian',
#  'cand',
#  'cap',
#  'capabilities',
#  'captur',
#  'captured',
#  'car',
#  'caravan',
#  'caravans',
#  'card',
#  'cards',
#  'care',
#  'cared',
#  'career',
#  'cares',
#  'carries',
#  'carroll',
#  'carry',
#  'case',
#  'cashslave',
#  'cassie',
#  'cast',
#  'casted',
#  'casually',
#  'cat',
#  'catch',
#  'catholic',
#  'cause',
#  'cavs',
#  'cda',
#  'cdnpoli',
#  'ce',
#  'cecy',
#  'celeb',
#  'celebrity',
#  'celestialsoph',
#  'censored',
#  'censoring',
#  'census',
#  'cernovich',
#  'certainly',
#  'certainty',
#  'chabby',
#  'chairs',
#  'challa',
#  'challenge',
#  'challenging',
#  'championships',
#  'chance',
#  'change',
#  'changed',
#  'changer',
#  'channel4',
#  'chaps',
#  'characteri',
#  'charged',
#  'charming',
#  'charts',
#  'chased',
#  'chatting',
#  'che',
#  'cheap',
#  'cheating',
#  'check',
#  'cheer',
#  'cheesy',
#  'cheeto',
#  'chemical',
#  'chicago',
#  'chicken',
#  'chicks',
#  'chief',
#  'child',
#  'childhood',
#  'children',
#  'chilling',
#  'chin',
#  'china',
#  'chris',
#  'chrislutolf',
#  'christ',
#  'christian',
#  'christmas',
#  'christywebs3',
#  'chronic',
#  'chuckle',
#  'chutiya',
#  'cirque',
#  'cis',
#  'cishet',
#  'cishetwhitemale',
#  'cited',
#  'citizens',
#  'city',
#  'civil',
#  'cl',
#  'claim',
#  'claimed',
#  'claimin',
#  'claiming',
#  'claims',
#  'clash',
#  'class',
#  'classic',
#  'clean',
#  'clearly',
#  'climate',
#  'clitty',
#  'close',
#  'closet',
#  'clout',
#  'clown',
#  'club',
#  'clue',
#  'clueless',
#  'coach',
#  'coaching',
#  'coates',
#  'cock',
#  'cocky',
#  'coco',
#  'cod',
#  'coinbase',
#  'cold',
#  'collect',
#  'collection',
#  'college',
#  'collision',
#  'color',
#  'colors',
#  'come',
#  'comeback',
#  'comedy',
#  'comes',
#  'comical',
#  'comin',
#  'coming',
#  'comment',
#  'comments',
#  'commie',
#  'commies',
#  'commit',
#  'committ',
#  'common',
#  'communities',
#  'community',
#  'comp',
#  'company',
#  'compared',
#  'comparing',
#  'complain',
#  'comple',
#  'complete',
#  'completely',
#  'complexes',
#  'compte',
#  'computer',
#  'condone',
#  'conf',
#  'conflat',
#  'confront',
#  'confused',
#  'congestion',
#  'congoers',
#  'congress',
#  'connected',
#  'connie48359391',
#  'connor',
#  'conor',
#  'conormcgregor',
#  'conq',
#  'consequences',
#  'conservative',
#  'conservatives',
#  'consider',
#  'considering',
#  'conspiracy',
#  'constantly',
#  'constitu',
#  'constituents',
#  'constitution',
#  'constitutional',
#  'constitutionally',
#  'contact',
#  'contacts',
#  'contempt',
#  'continue',
#  'continuously',
#  'contradicting',
#  'contre',
#  'control',
#  'conveniently',
#  'conversation',
#  'convert',
#  'cool',
#  'coolest',
#  'copy',
#  'corbyn',
#  'corner',
#  'correct',
#  'correctly',
#  'corrupt',
#  'cotton',
#  'couldn',
#  'council',
#  'countries',
#  'country',
#  'county',
#  'coup',
#  'couple',
#  'course',
#  'court',
#  'cousin',
#  'cov',
#  'coverage',
#  'covered',
#  'coward',
#  'cowardly',
#  'coworkers',
#  'cows',
#  'coz',
#  'cpc',
#  'craeven',
#  'crashed',
#  'cravings',
#  'crazed',
#  'crazy',
#  'cre',
#  'create',
#  'created',
#  'creates',
#  'creative',
#  'creature',
#  'credibly',
#  'credit',
#  'creep',
#  'creepy',
#  'crenshaw',
#  'cretins',
#  'crew',
#  'crime',
#  'criminal',
#  'criminals',
#  'critical',
#  'criticism',
#  'criticize',
#  'crooked',
#  'cropping',
#  'crossed',
#  'crossing',
#  'crowd',
#  'crunch',
#  'crush',
#  'cruz',
#  'crybaby',
#  'crying',
#  'cu',
#  'cuban',
#  'cubs',
#  'cuck',
#  'cuisine',
#  'cultures',
#  'cum',
#  'cunt',
#  'cunts',
#  'cup',
#  'current',
#  'curse',
#  'cus',
#  'cut',
#  'cute',
#  'cuz',
#  'cxpage',
#  'cyber',
#  'cynical',
#  'czechoslovakia',
#  'daaaamn',
#  'dad',
#  'daddy',
#  'dads',
#  'daily',
#  'damage',
#  'damn',
#  'dance',
#  'dancing',
#  'dangerous',
#  'daniels',
#  'dar',
#  'dare',
#  'dates',
#  'dating',
#  'dats',
#  'dave',
#  'davidhogg111',
#  'dawgs',
#  'day',
#  'days',
#  'deadly',
#  'deaf',
#  'deal',
#  'dealing',
#  'dealt',
#  'dear',
#  'death',
#  'debby',
#  'debut',
#  'decade',
#  'decades',
#  'decide',
#  'decided',
#  'decieved',
#  'decievers',
#  'declining',
#  'decolonialblack',
#  'dee',
#  'deems',
#  'deep',
#  'defeated',
#  'defective',
#  'defend',
#  'defending',
#  'define',
#  'defined',
#  'definitely',
#  'definition',
#  'degraded',
#  'delete',
#  'deliberately',
#  'delicious',
#  'demented',
#  'democrat',
#  'democrats',
#  'demonstrates',
#  'dems',
#  'dents',
#  'deny',
#  'dependent',
#  'deploy',
#  'deploying',
#  'deported',
#  'deprived',
#  'derogatory',
#  'descent',
#  'deserve',
#  'deserves',
#  'designed',
#  'desperate',
#  'destroyed',
#  'destroying',
#  'destruct',
#  'determi',
#  'detona',
#  'developer',
#  'devin',
#  'di',
#  'diageo',
#  'dick',
#  'did',
#  'didn',
#  'didnt',
#  'die',
#  'diealready',
#  'died',
#  'diesel',
#  'diet',
#  'dif',
#  'diff',
#  'difference',
#  'different',
#  'difficult',
#  'digger',
#  'dildo',
#  'diminish',
#  'diminishing',
#  'dimwit',
#  'direct',
#  'directed',
#  'direction',
#  'directly',
#  'director',
#  'dirty',
#  'dis',
#  'disagree',
#  'disappointed',
#  'disc',
#  'discern',
#  'discourse',
#  'discrimination',
#  'discriminatory',
#  'discussion',
#  'disenfra',
#  'disenfranchised',
#  'disgusses',
#  'disgusted',
#  'disgusting',
#  'disgustingly',
#  'dishing',
#  'dismissed',
#  'disney',
#  'disregard',
#  'disruptivesigna',
#  'distance',
#  'distract',
#  'district',
#  'disturbing',
#  'ditched',
#  'dixie',
#  'django',
#  'dkfjkd',
#  'dloesch',
#  'dna',
#  'doa',
#  'doc',
#  'doctors',
#  'doctrines',
#  'dodie',
#  'does',
#  'doesn',
#  'doesnt',
#  'dog',
#  'dogs',
#  'doing',
#  'doit',
#  'doll',
#  'dom',
#  'domain',
#  'dominated',
#  'domme',
#  'don',
#  'donald',
#  'donkeys',
#  'donny',
#  'dont',
#  'donthecon',
#  'donuts',
#  'doo',
#  'dooby',
#  'doogie',
#  'door',
#  'dope',
#  'dotus',
#  'doubt',
#  'douche',
#  'douchebag',
#  'doughy',
#  'douglass',
#  'dozens',
#  'dp',
#  'dr',
#  'draft',
#  'dragging',
#  'drama',
#  'dread',
#  'dream',
#  'dreams',
#  'dress',
#  'dri',
#  'drinks',
#  'drive',
#  'driver',
#  'drivers',
#  'drop',
#  'drugs',
#  'dry',
#  'du',
#  'dubai',
#  'duck',
#  'dude',
#  ...]

# %%
print("Prediction")
X = vectorizer.transform([""])
predicted = model.predict(X)
print(predicted)
# Out:
# Prediction
# [1]
