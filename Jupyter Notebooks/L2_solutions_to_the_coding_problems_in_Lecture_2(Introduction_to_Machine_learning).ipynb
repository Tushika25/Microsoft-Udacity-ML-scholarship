# %% [markdown]
# <a href="https://colab.research.google.com/github/ananyaynkit/Microsoft-Udacity-ML-scholarship/blob/master/L2_solutions_to_the_coding_problems_in_Lecture_2(Introduction_to_Machine_learning).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

x = [-5, 10, 15]

u = 7 #mean
s = 10 #standard deviation

#step 1: convert x into array using numpy.array() function
#step 2: place the entire problem into the formula as shown below:

((np.array(x)-7)/s)
# Out:
# array([-1.2,  0.3,  0.8])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
xs = -5 #xsmall
xl = 15 #xlarge

#normalization:

(np.array(x) - xs)/ (xl - xs)
# Out:
# array([0.  , 0.75, 1.  ])

# %%
#here array([0. , 0.75, 1.]) in simpler terms is equal to [0.0 , 0.75, 1.0]
